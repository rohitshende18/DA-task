# %%
import pandas as pd

# %%
x = pd.read_csv ("E:/data/ECOM_sales.csv")

# %%
z1 =x.iloc[0:10]

# %%
y = z1.to_dict(orient = 'records')

# %%
y
# Out:
# [{'CG-12520': 'DV-13045',
#   'Claire Gute': 'Darrin Van Huff',
#   'Consumer': 'Corporate',
#   '67': 31,
#   'United States': 'United States',
#   'Henderson': 'Los Angeles',
#   'Kentucky': 'California',
#   '42420': 90036,
#   'South': 'West'},
#  {'CG-12520': 'SO-20335',
#   'Claire Gute': "Sean O'Donnell",
#   'Consumer': 'Consumer',
#   '67': 65,
#   'United States': 'United States',
#   'Henderson': 'Fort Lauderdale',
#   'Kentucky': 'Florida',
#   '42420': 33311,
#   'South': 'South'},
#  {'CG-12520': 'BH-11710',
#   'Claire Gute': 'Brosina Hoffman',
#   'Consumer': 'Consumer',
#   '67': 20,
#   'United States': 'United States',
#   'Henderson': 'Los Angeles',
#   'Kentucky': 'California',
#   '42420': 90032,
#   'South': 'West'},
#  {'CG-12520': 'AA-10480',
#   'Claire Gute': 'Andrew Allen',
#   'Consumer': 'Consumer',
#   '67': 50,
#   'United States': 'United States',
#   'Henderson': 'Concord',
#   'Kentucky': 'North Carolina',
#   '42420': 28027,
#   'South': 'South'},
# ...

# %%
x = pd.read_excel ("E:/data/population-2030-2040.xlsx")

# %%
x
# Out:
#        LocID             Location    Time AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0        4.0          Afghanistan  2030.0    0-4          0.0         5.0
# 1        8.0              Albania  2030.0    0-4          0.0         5.0
# 2       12.0              Algeria  2030.0    0-4          0.0         5.0
# 3       24.0               Angola  2030.0    0-4          0.0         5.0
# 4       28.0  Antigua and Barbuda  2030.0    0-4          0.0         5.0
# ...      ...                  ...     ...    ...          ...         ...
# 45971  308.0              Grenada  2040.0   100+        100.0        -1.0
# 45972  426.0              Lesotho  2040.0   100+        100.0        -1.0
# 45973  516.0              Namibia  2040.0   100+        100.0        -1.0
# 45974  690.0           Seychelles  2040.0   100+        100.0        -1.0
# 45975  776.0                Tonga  2040.0   100+        100.0        -1.0
#
#         PopMale  PopFemale  PopTotal
# 0      3020.571   2871.955  5892.526
# ...
