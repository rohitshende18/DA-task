# %%
import  requests as rq

# %%
import requests as rq

url = 'https://www.amazon.in/Mens-Sunglasses-Eyewear-Accessories/b?ie=UTF8&node=1968032031'

rResp = rq.get(url)

# %%
print(rResp)
# Out:
# <Response [200]>

# %%
rResp.status_code
# Out:
# 200

# %%
print(rResp.content.decode('utf-8'))
# Out:
# <!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
#
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta http-equiv='x-dns-prefetch-control' content='on'>
# <link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com" crossorigin>
# <link rel="preconnect" href="https://images-eu.ssl-images-amazon.com" crossorigin>
# <link rel="dns-prefetch" href="https://m.media-amazon.com" crossorigin>
# <link rel="preconnect" href="https://m.media-amazon.com" crossorigin>
# <link rel="dns-prefetch" href="https://completion.amazon.com" crossorigin>
# <link rel="preconnect" href="https://completion.amazon.com" crossorigin>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
#
# ...

# %%
jResp =rResp.content.decode('utf-8')

print(jResp)
# Out:
# <!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
#
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta http-equiv='x-dns-prefetch-control' content='on'>
# <link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com" crossorigin>
# <link rel="preconnect" href="https://images-eu.ssl-images-amazon.com" crossorigin>
# <link rel="dns-prefetch" href="https://m.media-amazon.com" crossorigin>
# <link rel="preconnect" href="https://m.media-amazon.com" crossorigin>
# <link rel="dns-prefetch" href="https://completion.amazon.com" crossorigin>
# <link rel="preconnect" href="https://completion.amazon.com" crossorigin>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
#
# ...

# %%
print(f'Content-Type = {lHeader["Content-Type"]}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(f'Content-Type = {lHeader["Content-Type"]}')
#
# NameError: name 'lHeader' is not defined

# %%
def Content_type(1Headers):
    return f'({'1Headers'})'
# Out:
#   Cell In[11], line 1
#     def Content_type(1Headers):
#                      ^
# SyntaxError: invalid decimal literal

# %%
def greet(name):
    """
    This function greets the provided name.

    Args:
        name (str): The name to greet.

    Returns:
        str: A greeting message.
    """
    return f"Hello, {name}!"
